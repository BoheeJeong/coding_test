# %% [markdown]
# # 프로그래머스 | Level 1 | Python 3 | 평균 구하기
# ## 문제
# 정수를 담고 있는 배열 arr의 평균값을 return하는 함수, solution을 완성해보세요.

# %%
arr = [1,2,3,4]

size = len(arr)
avg =sum(arr)/size

print(avg)
# Out:
# 2.5

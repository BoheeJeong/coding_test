# %% [markdown]
# # 프로그래머스 | Level 1 | Python 3 | 약수의 합
# ## 문제
# 정수 n을 입력받아 n의 약수를 모두 더한 값을 리턴하는 함수, solution을 완성해주세요.
#
# ## 제한사항
# - n은 0 이상 3000이하인 정수입니다.

# %%
n=12

a=[]
for i in range(1,n+1):
  if n%i ==0:
    a.append(i)

print(a)
sum(a)
# Out:
# [1, 2, 3, 4, 6, 12]
# 28

# %% [markdown]
# # 프로그래머스 | Level 1 | Python 3 | 문자열을 정수로 바꾸기
# ## 문제
# 문자열 s를 숫자로 변환한 결과를 반환하는 함수, solution을 완성하세요.
#
#
# ## 제한조건
# - s의 길이는 1 이상 5이하입니다.
# - s의 맨앞에는 부호(+, -)가 올 수 있습니다.
# - s는 부호와 숫자로만 이루어져있습니다.
# - s는 "0"으로 시작하지 않습니다.

# %%
str = "-12345"
print(str)


listing=list(str)

if listing[0] != "-":
  answer = int(str)

if listing[0] == "-":
  answer = (-1)*int(str.replace("-",""))

print(answer)
# Out:
# -12345
# -12345

# %%
def solution(str):
    listing=list(str)

    if listing[0] != "-":
        answer = int(str)

    if listing[0] == "-":
        answer = (-1)*int(str.replace("-",""))
    return answer

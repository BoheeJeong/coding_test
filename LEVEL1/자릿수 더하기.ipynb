# %% [markdown]
# # 프로그래머스 | Level 1 | Python 3 | 자릿수 더하기
# ## 문제
# 자연수 N이 주어지면, N의 각 자릿수의 합을 구해서 return 하는 solution 함수를 만들어 주세요.
# 예를들어 N = 123이면 1 + 2 + 3 = 6을 return 하면 됩니다.

# %%
N=987

print(N)
a=list(str(N))

result=0
for i in a:
  result+=int(i)

print(result)
# Out:
# 987
# 24

# %%
def solution(n):
  a=list(str(N))

  result=0
  for i in a:
    result+=int(i)


  return result
